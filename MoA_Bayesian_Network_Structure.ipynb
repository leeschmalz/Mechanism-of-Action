# %% [markdown]
# ## Bayesian Network Structure Playground
#
# Current structure simply uses the top 50 or so correlated features (use_top_corrs) and adds them as edges to the network, no structure learning or network optimization has been done; the current structure is a bit random, only using correlated feature data. Running through some of the train data, the current network currently correctly predicts the target within the top 3, 18% of the time. Considering the facts that this was sort of a random guess at model structure and that there are 206 targets to choose from (Expected value 3/206 = 1.4% for random guessing), the model type seems to be showing some promise. Ideas for future development:
#
# 1. Since the network runs slowly at only 25-30 nodes, we will need to find a way to include information for more features.
#     -the final network may need to be much more sparse, only using very select proven connections. How to find these?
#
# 2. For simplicity sake, features are currently encoded as high / low (1, 0). This may be causing a large information loss. Potentially decide on a better discretezation scheme. One idea I had for this is simply using mean +- stddev buckets based on the distribution of each feature (they seem to all be roughly normal).
#
# 3. Somehow optimize directionality of connections: g-0 --> g-1 or g-1 --> g-0?
#     -maybe iteratively flip connections in many different networks and see if certain directionality of connections works
#     better on average.
#     -I've currently only studied Bayesian Networks, but perhaps an undirected structure would better fit this problem
#
# 4. Could we use a clustering algorithm on the principal components as a precursor to this model? Looking at only the first 2 principle components, there are some very obvious clusters. Maybe we could tell the Bayes Net which answers are wrong right out the gate.
#
# 5. Ideal parent search: look into this
#     -https://jmlr.csail.mit.edu/papers/volume8/elidan07a/elidan07a.pdf
#
# 6. This paper uses a constraint based two-step clustering and connecting approach. Form clusters of nodes, then decide connectivity of clusters. Just from a theoretical perspective, this seems to fit the biological gene expression paradigm.
#     -https://zhangyk8.github.io/publications/Thesis.pdf
#
# 7. This paper outlines methods of constraining and scoring Bayesian Networks
#     -https://jmlr.csail.mit.edu/papers/volume12/decampos11a/decampos11a.pdf

# %%
import pandas as pd
from pgmpy.models import BayesianModel
from tqdm import tqdm
import numpy as np
from pgmpy.inference import VariableElimination
import random
import networkx as nx
import pylab as plt

# %%
train_df = pd.read_csv('train_features_binary.csv')
train_df.drop('Unnamed: 0',inplace=True,axis=1)

# %%
corr_df = pd.read_csv('feature_correlation.csv')
corr_df.drop('Unnamed: 0',inplace=True,axis=1)

# %%
use_top_corrs = 50

#get network connections
#network looks like [(node1,node2),...]
network = []
for i in range(len(corr_df[:use_top_corrs])):
    network.append((corr_df['feature1'][i],corr_df['feature2'][i]))

# %%
#get unpacked list of nodes
nodes_in_network = []
for item in network:
    for i in [0,1]:
        nodes_in_network.append(item[i])

# %%
model = BayesianModel([network[0]])

#add edges - pgmpy automatically errors if edge does not form DAG use try, except to ensure DAG
for edge in network[1:]:
        #whichever has more children 
        try:
            if len(model.get_children(edge[0])) < len(model.get_children(edge[0])):
                model.add_edge(edge[0],edge[1])
            else:
                model.add_edge(edge[1],edge[0])
        except:
            model.add_edge(edge[0],edge[1])

#if node is leaf, connect to target
for node in nodes_in_network:
    if node in model.get_leaves():
        model.add_edge(node,'target')

# %%
#model.fit automatically finds cpds for each node
model.fit(train_df)

#compute variable eliminations for node independencies to speed up model 
infer = VariableElimination(model)

# %%
nx.draw(model, with_labels=True)
plt.show()

# %%
# get samples to check training data accuracy 
# evidence dict looks like {0 : {'g-0' : 0,'g-1' : 1,...}, 1 : {'g-0' : 0,'g-1' : 1,...},...}
evidence = {}
for i in tqdm(range(len(train_df))):
    evidence[i] = {}
    for node in nodes_in_network:
        evidence[i][node] = train_df[node][i]
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 16844/16844 [00:07<00:00, 2285.23it/s]

# %%
# check if actual target is within top 'n' predictions and calculation accuracy over 'total' samples
n = 3
preds = []
count_correct = 0
total = 500

for i in tqdm(range(total)):
    preds = []
    q = infer.query(variables=['target'],evidence=evidence[i],show_progress=False)
    top_n_idx = np.argsort(q.values)[-n:]
    top_n_values = [q.values[i] for i in top_n_idx]
    actual_target = train_df['target'][i]
    if i == 6:
        print('Sample prediciton \n') #obviously I chose one that is a correct prediction
        print(f'Actual Target: {actual_target}')
        print('Predicted Target: \n')
    for j,k in enumerate(top_n_idx):
        name = q.state_names['target'][k]
        preds.append(name)
        if i == 6:
            print(f'{name}: {top_n_values[j]}')
            
    if actual_target in preds:
        count_correct += 1
print(f'% in top {n}: {count_correct / total * 100}')
# Out:
#   1%|█▏                                                                                | 7/500 [00:49<57:58,  7.06s/it]
# Sample prediciton
#
# Actual Target: cdk_inhibitor
# Predicted Target:
#
# raf_inhibitor: 0.04031007751937985
# egfr_inhibitor: 0.04573643410852714
# cdk_inhibitor: 0.07519379844961242
# 100%|████████████████████████████████████████████████████████████████████████████████| 500/500 [58:57<00:00,  7.08s/it]
# % in top 3: 18.0

# %%
print(f'Sample table of target probability distribution \n')
print(q)
# Out:
# Sample table of target probability distribution
#
# +---------------------------------------------------------+---------------+
# | target                                                  |   phi(target) |
# +=========================================================+===============+
# | target(11-beta-hsd1_inhibitor)                          |        0.0016 |
# +---------------------------------------------------------+---------------+
# | target(5-alpha_reductase_inhibitor)                     |        0.0008 |
# +---------------------------------------------------------+---------------+
# | target(acat_inhibitor)                                  |        0.0016 |
# +---------------------------------------------------------+---------------+
# | target(acetylcholine_receptor_agonist)                  |        0.0111 |
# +---------------------------------------------------------+---------------+
# | target(acetylcholine_receptor_antagonist)               |        0.0199 |
# +---------------------------------------------------------+---------------+
# | target(acetylcholinesterase_inhibitor)                  |        0.0088 |
# +---------------------------------------------------------+---------------+
# | target(adenosine_receptor_agonist)                      |        0.0040 |
# +---------------------------------------------------------+---------------+
# | target(adenosine_receptor_antagonist)                   |        0.0127 |
# +---------------------------------------------------------+---------------+
# | target(adenylyl_cyclase_activator)                      |        0.0008 |
# +---------------------------------------------------------+---------------+
# | target(adrenergic_receptor_agonist)                     |        0.0127 |
# +---------------------------------------------------------+---------------+
# | target(adrenergic_receptor_antagonist)                  |        0.0223 |
# +---------------------------------------------------------+---------------+
# | target(akt_inhibitor)                                   |        0.0000 |
# +---------------------------------------------------------+---------------+
# | target(aldehyde_dehydrogenase_inhibitor)                |        0.0000 |
# +---------------------------------------------------------+---------------+
# | target(alk_inhibitor)                                   |        0.0008 |
# +---------------------------------------------------------+---------------+
# | target(ampk_activator)                                  |        0.0008 |
# +---------------------------------------------------------+---------------+
# | target(analgesic)                                       |        0.0016 |
# +---------------------------------------------------------+---------------+
# | target(androgen_receptor_agonist)                       |        0.0064 |
# +---------------------------------------------------------+---------------+
# | target(androgen_receptor_antagonist)                    |        0.0095 |
# +---------------------------------------------------------+---------------+
# | target(anesthetic_-_local)                              |        0.0111 |
# +---------------------------------------------------------+---------------+
# | target(angiogenesis_inhibitor)                          |        0.0048 |
# +---------------------------------------------------------+---------------+
# | target(angiotensin_receptor_antagonist)                 |        0.0032 |
# +---------------------------------------------------------+---------------+
# | target(anti-inflammatory)                               |        0.0048 |
# +---------------------------------------------------------+---------------+
# | target(antiarrhythmic)                                  |        0.0008 |
# +---------------------------------------------------------+---------------+
# | target(antibiotic)                                      |        0.0032 |
# +---------------------------------------------------------+---------------+
# | target(anticonvulsant)                                  |        0.0024 |
# +---------------------------------------------------------+---------------+
# | target(antifungal)                                      |        0.0000 |
# +---------------------------------------------------------+---------------+
# | target(antihistamine)                                   |        0.0032 |
# +---------------------------------------------------------+---------------+
# | target(antimalarial)                                    |        0.0024 |
# +---------------------------------------------------------+---------------+
# | target(antioxidant)                                     |        0.0040 |
# +---------------------------------------------------------+---------------+
# | target(antiprotozoal)                                   |        0.0024 |
# +---------------------------------------------------------+---------------+
# | target(antiviral)                                       |        0.0008 |
# +---------------------------------------------------------+---------------+
# | target(apoptosis_stimulant)                             |        0.0008 |
# +---------------------------------------------------------+---------------+
# | target(aromatase_inhibitor)                             |        0.0032 |
# +---------------------------------------------------------+---------------+
# | target(atm_kinase_inhibitor)                            |        0.0000 |
# +---------------------------------------------------------+---------------+
# | target(atp-sensitive_potassium_channel_antagonist)      |        0.0000 |
# +---------------------------------------------------------+---------------+
# | target(atp_synthase_inhibitor)                          |        0.0000 |
# +---------------------------------------------------------+---------------+
# | target(atpase_inhibitor)                                |        0.0095 |
# +---------------------------------------------------------+---------------+
# | target(atr_kinase_inhibitor)                            |        0.0024 |
# +---------------------------------------------------------+---------------+
# | target(aurora_kinase_inhibitor)                         |        0.0024 |
# +---------------------------------------------------------+---------------+
# | target(autotaxin_inhibitor)                             |        0.0008 |
# +---------------------------------------------------------+---------------+
# | target(bacterial_30s_ribosomal_subunit_inhibitor)       |        0.0048 |
# +---------------------------------------------------------+---------------+
# | target(bacterial_50s_ribosomal_subunit_inhibitor)       |        0.0048 |
# +---------------------------------------------------------+---------------+
# | target(bacterial_antifolate)                            |        0.0016 |
# +---------------------------------------------------------+---------------+
# | target(bacterial_cell_wall_synthesis_inhibitor)         |        0.0159 |
# +---------------------------------------------------------+---------------+
# | target(bacterial_dna_gyrase_inhibitor)                  |        0.0064 |
# +---------------------------------------------------------+---------------+
# | target(bacterial_dna_inhibitor)                         |        0.0111 |
# +---------------------------------------------------------+---------------+
# | target(bacterial_membrane_integrity_inhibitor)          |        0.0008 |
# +---------------------------------------------------------+---------------+
# | target(bcl_inhibitor)                                   |        0.0016 |
# +---------------------------------------------------------+---------------+
# | target(bcr-abl_inhibitor)                               |        0.0024 |
# +---------------------------------------------------------+---------------+
# | target(benzodiazepine_receptor_agonist)                 |        0.0040 |
# +---------------------------------------------------------+---------------+
# | target(beta_amyloid_inhibitor)                          |        0.0016 |
# +---------------------------------------------------------+---------------+
# | target(bromodomain_inhibitor)                           |        0.0040 |
# +---------------------------------------------------------+---------------+
# | target(btk_inhibitor)                                   |        0.0032 |
# +---------------------------------------------------------+---------------+
# | target(calcineurin_inhibitor)                           |        0.0000 |
# +---------------------------------------------------------+---------------+
# | target(calcium_channel_blocker)                         |        0.0159 |
# +---------------------------------------------------------+---------------+
# | target(cannabinoid_receptor_agonist)                    |        0.0064 |
# +---------------------------------------------------------+---------------+
# | target(cannabinoid_receptor_antagonist)                 |        0.0048 |
# +---------------------------------------------------------+---------------+
# | target(carbonic_anhydrase_inhibitor)                    |        0.0016 |
# +---------------------------------------------------------+---------------+
# | target(casein_kinase_inhibitor)                         |        0.0024 |
# +---------------------------------------------------------+---------------+
# | target(caspase_activator)                               |        0.0016 |
# +---------------------------------------------------------+---------------+
# | target(catechol_o_methyltransferase_inhibitor)          |        0.0016 |
# +---------------------------------------------------------+---------------+
# | target(cc_chemokine_receptor_antagonist)                |        0.0064 |
# +---------------------------------------------------------+---------------+
# | target(cck_receptor_antagonist)                         |        0.0008 |
# +---------------------------------------------------------+---------------+
# | target(cdk_inhibitor)                                   |        0.0159 |
# +---------------------------------------------------------+---------------+
# | target(chelating_agent)                                 |        0.0040 |
# +---------------------------------------------------------+---------------+
# | target(chk_inhibitor)                                   |        0.0040 |
# +---------------------------------------------------------+---------------+
# | target(chloride_channel_blocker)                        |        0.0016 |
# +---------------------------------------------------------+---------------+
# | target(cholesterol_inhibitor)                           |        0.0024 |
# +---------------------------------------------------------+---------------+
# | target(cholinergic_receptor_antagonist)                 |        0.0040 |
# +---------------------------------------------------------+---------------+
# | target(coagulation_factor_inhibitor)                    |        0.0008 |
# +---------------------------------------------------------+---------------+
# | target(corticosteroid_agonist)                          |        0.0016 |
# +---------------------------------------------------------+---------------+
# | target(cyclooxygenase_inhibitor)                        |        0.0342 |
# +---------------------------------------------------------+---------------+
# | target(cytochrome_p450_inhibitor)                       |        0.0103 |
# +---------------------------------------------------------+---------------+
# | target(dihydrofolate_reductase_inhibitor)               |        0.0032 |
# +---------------------------------------------------------+---------------+
# | target(dipeptidyl_peptidase_inhibitor)                  |        0.0008 |
# +---------------------------------------------------------+---------------+
# | target(diuretic)                                        |        0.0000 |
# +---------------------------------------------------------+---------------+
# | target(dna_alkylating_agent)                            |        0.0040 |
# +---------------------------------------------------------+---------------+
# | target(dna_inhibitor)                                   |        0.0223 |
# +---------------------------------------------------------+---------------+
# | target(dopamine_receptor_agonist)                       |        0.0127 |
# +---------------------------------------------------------+---------------+
# | target(dopamine_receptor_antagonist)                    |        0.0286 |
# +---------------------------------------------------------+---------------+
# | target(egfr_inhibitor)                                  |        0.0056 |
# +---------------------------------------------------------+---------------+
# | target(elastase_inhibitor)                              |        0.0000 |
# +---------------------------------------------------------+---------------+
# | target(erbb2_inhibitor)                                 |        0.0000 |
# +---------------------------------------------------------+---------------+
# | target(estrogen_receptor_agonist)                       |        0.0183 |
# +---------------------------------------------------------+---------------+
# | target(estrogen_receptor_antagonist)                    |        0.0024 |
# +---------------------------------------------------------+---------------+
# | target(faah_inhibitor)                                  |        0.0000 |
# +---------------------------------------------------------+---------------+
# | target(farnesyltransferase_inhibitor)                   |        0.0000 |
# +---------------------------------------------------------+---------------+
# | target(fatty_acid_receptor_agonist)                     |        0.0008 |
# +---------------------------------------------------------+---------------+
# | target(fgfr_inhibitor)                                  |        0.0016 |
# +---------------------------------------------------------+---------------+
# | target(flt3_inhibitor)                                  |        0.0191 |
# +---------------------------------------------------------+---------------+
# | target(focal_adhesion_kinase_inhibitor)                 |        0.0008 |
# +---------------------------------------------------------+---------------+
# | target(free_radical_scavenger)                          |        0.0008 |
# +---------------------------------------------------------+---------------+
# | target(fungal_squalene_epoxidase_inhibitor)             |        0.0016 |
# +---------------------------------------------------------+---------------+
# | target(gaba_receptor_agonist)                           |        0.0072 |
# +---------------------------------------------------------+---------------+
# | target(gaba_receptor_antagonist)                        |        0.0095 |
# +---------------------------------------------------------+---------------+
# | target(gamma_secretase_inhibitor)                       |        0.0072 |
# +---------------------------------------------------------+---------------+
# | target(glucocorticoid_receptor_agonist)                 |        0.0111 |
# +---------------------------------------------------------+---------------+
# | target(glutamate_inhibitor)                             |        0.0008 |
# +---------------------------------------------------------+---------------+
# | target(glutamate_receptor_agonist)                      |        0.0056 |
# +---------------------------------------------------------+---------------+
# | target(glutamate_receptor_antagonist)                   |        0.0326 |
# +---------------------------------------------------------+---------------+
# | target(gonadotropin_receptor_agonist)                   |        0.0016 |
# +---------------------------------------------------------+---------------+
# | target(gsk_inhibitor)                                   |        0.0064 |
# +---------------------------------------------------------+---------------+
# | target(hcv_inhibitor)                                   |        0.0000 |
# +---------------------------------------------------------+---------------+
# | target(hdac_inhibitor)                                  |        0.0080 |
# +---------------------------------------------------------+---------------+
# | target(histamine_receptor_agonist)                      |        0.0119 |
# +---------------------------------------------------------+---------------+
# | target(histamine_receptor_antagonist)                   |        0.0167 |
# +---------------------------------------------------------+---------------+
# | target(histone_lysine_demethylase_inhibitor)            |        0.0024 |
# +---------------------------------------------------------+---------------+
# | target(histone_lysine_methyltransferase_inhibitor)      |        0.0016 |
# +---------------------------------------------------------+---------------+
# | target(hiv_inhibitor)                                   |        0.0048 |
# +---------------------------------------------------------+---------------+
# | target(hmgcr_inhibitor)                                 |        0.0111 |
# +---------------------------------------------------------+---------------+
# | target(hsp_inhibitor)                                   |        0.0016 |
# +---------------------------------------------------------+---------------+
# | target(igf-1_inhibitor)                                 |        0.0000 |
# +---------------------------------------------------------+---------------+
# | target(ikk_inhibitor)                                   |        0.0016 |
# +---------------------------------------------------------+---------------+
# | target(imidazoline_receptor_agonist)                    |        0.0016 |
# +---------------------------------------------------------+---------------+
# | target(immunosuppressant)                               |        0.0032 |
# +---------------------------------------------------------+---------------+
# | target(insulin_secretagogue)                            |        0.0016 |
# +---------------------------------------------------------+---------------+
# | target(insulin_sensitizer)                              |        0.0024 |
# +---------------------------------------------------------+---------------+
# | target(integrin_inhibitor)                              |        0.0016 |
# +---------------------------------------------------------+---------------+
# | target(jak_inhibitor)                                   |        0.0016 |
# +---------------------------------------------------------+---------------+
# | target(kit_inhibitor)                                   |        0.0231 |
# +---------------------------------------------------------+---------------+
# | target(laxative)                                        |        0.0000 |
# +---------------------------------------------------------+---------------+
# | target(leukotriene_inhibitor)                           |        0.0000 |
# +---------------------------------------------------------+---------------+
# | target(leukotriene_receptor_antagonist)                 |        0.0064 |
# +---------------------------------------------------------+---------------+
# | target(lipase_inhibitor)                                |        0.0008 |
# +---------------------------------------------------------+---------------+
# | target(lipoxygenase_inhibitor)                          |        0.0056 |
# +---------------------------------------------------------+---------------+
# | target(lxr_agonist)                                     |        0.0000 |
# +---------------------------------------------------------+---------------+
# | target(mdm_inhibitor)                                   |        0.0040 |
# +---------------------------------------------------------+---------------+
# | target(mek_inhibitor)                                   |        0.0056 |
# +---------------------------------------------------------+---------------+
# | target(membrane_integrity_inhibitor)                    |        0.0040 |
# +---------------------------------------------------------+---------------+
# | target(mineralocorticoid_receptor_antagonist)           |        0.0016 |
# +---------------------------------------------------------+---------------+
# | target(monoacylglycerol_lipase_inhibitor)               |        0.0000 |
# +---------------------------------------------------------+---------------+
# | target(monoamine_oxidase_inhibitor)                     |        0.0064 |
# +---------------------------------------------------------+---------------+
# | target(monopolar_spindle_1_kinase_inhibitor)            |        0.0008 |
# +---------------------------------------------------------+---------------+
# | target(mtor_inhibitor)                                  |        0.0024 |
# +---------------------------------------------------------+---------------+
# | target(mucolytic_agent)                                 |        0.0024 |
# +---------------------------------------------------------+---------------+
# | target(neuropeptide_receptor_antagonist)                |        0.0032 |
# +---------------------------------------------------------+---------------+
# | target(nfkb_inhibitor)                                  |        0.0072 |
# +---------------------------------------------------------+---------------+
# | target(nicotinic_receptor_agonist)                      |        0.0008 |
# +---------------------------------------------------------+---------------+
# | target(nitric_oxide_donor)                              |        0.0008 |
# +---------------------------------------------------------+---------------+
# | target(nitric_oxide_production_inhibitor)               |        0.0000 |
# +---------------------------------------------------------+---------------+
# | target(nitric_oxide_synthase_inhibitor)                 |        0.0040 |
# +---------------------------------------------------------+---------------+
# | target(norepinephrine_reuptake_inhibitor)               |        0.0000 |
# +---------------------------------------------------------+---------------+
# | target(nrf2_activator)                                  |        0.0008 |
# +---------------------------------------------------------+---------------+
# | target(opioid_receptor_agonist)                         |        0.0048 |
# +---------------------------------------------------------+---------------+
# | target(opioid_receptor_antagonist)                      |        0.0064 |
# +---------------------------------------------------------+---------------+
# | target(orexin_receptor_antagonist)                      |        0.0008 |
# +---------------------------------------------------------+---------------+
# | target(p-glycoprotein_inhibitor)                        |        0.0016 |
# +---------------------------------------------------------+---------------+
# | target(p38_mapk_inhibitor)                              |        0.0024 |
# +---------------------------------------------------------+---------------+
# | target(parp_inhibitor)                                  |        0.0024 |
# +---------------------------------------------------------+---------------+
# | target(pdgfr_inhibitor)                                 |        0.0247 |
# +---------------------------------------------------------+---------------+
# | target(pdk_inhibitor)                                   |        0.0008 |
# +---------------------------------------------------------+---------------+
# | target(phosphodiesterase_inhibitor)                     |        0.0215 |
# +---------------------------------------------------------+---------------+
# | target(phospholipase_inhibitor)                         |        0.0024 |
# +---------------------------------------------------------+---------------+
# | target(pi3k_inhibitor)                                  |        0.0032 |
# +---------------------------------------------------------+---------------+
# | target(pkc_inhibitor)                                   |        0.0016 |
# +---------------------------------------------------------+---------------+
# | target(potassium_channel_activator)                     |        0.0040 |
# +---------------------------------------------------------+---------------+
# | target(potassium_channel_antagonist)                    |        0.0056 |
# +---------------------------------------------------------+---------------+
# | target(ppar_receptor_agonist)                           |        0.0048 |
# +---------------------------------------------------------+---------------+
# | target(ppar_receptor_antagonist)                        |        0.0000 |
# +---------------------------------------------------------+---------------+
# | target(progesterone_receptor_agonist)                   |        0.0088 |
# +---------------------------------------------------------+---------------+
# | target(progesterone_receptor_antagonist)                |        0.0016 |
# +---------------------------------------------------------+---------------+
# | target(prostaglandin_inhibitor)                         |        0.0024 |
# +---------------------------------------------------------+---------------+
# | target(prostanoid_receptor_antagonist)                  |        0.0032 |
# +---------------------------------------------------------+---------------+
# | target(proteasome_inhibitor)                            |        0.0000 |
# +---------------------------------------------------------+---------------+
# | target(protein_kinase_inhibitor)                        |        0.0032 |
# +---------------------------------------------------------+---------------+
# | target(protein_phosphatase_inhibitor)                   |        0.0008 |
# +---------------------------------------------------------+---------------+
# | target(protein_synthesis_inhibitor)                     |        0.0032 |
# +---------------------------------------------------------+---------------+
# | target(protein_tyrosine_kinase_inhibitor)               |        0.0008 |
# +---------------------------------------------------------+---------------+
# | target(radiopaque_medium)                               |        0.0032 |
# +---------------------------------------------------------+---------------+
# | target(raf_inhibitor)                                   |        0.0127 |
# +---------------------------------------------------------+---------------+
# | target(ras_gtpase_inhibitor)                            |        0.0032 |
# +---------------------------------------------------------+---------------+
# | target(retinoid_receptor_agonist)                       |        0.0040 |
# +---------------------------------------------------------+---------------+
# | target(retinoid_receptor_antagonist)                    |        0.0008 |
# +---------------------------------------------------------+---------------+
# | target(rho_associated_kinase_inhibitor)                 |        0.0016 |
# +---------------------------------------------------------+---------------+
# | target(ribonucleoside_reductase_inhibitor)              |        0.0008 |
# +---------------------------------------------------------+---------------+
# | target(rna_polymerase_inhibitor)                        |        0.0016 |
# +---------------------------------------------------------+---------------+
# | target(serotonin_receptor_agonist)                      |        0.0191 |
# +---------------------------------------------------------+---------------+
# | target(serotonin_receptor_antagonist)                   |        0.0318 |
# +---------------------------------------------------------+---------------+
# | target(serotonin_reuptake_inhibitor)                    |        0.0000 |
# +---------------------------------------------------------+---------------+
# | target(sigma_receptor_agonist)                          |        0.0064 |
# +---------------------------------------------------------+---------------+
# | target(sigma_receptor_antagonist)                       |        0.0040 |
# +---------------------------------------------------------+---------------+
# | target(smoothened_receptor_antagonist)                  |        0.0016 |
# +---------------------------------------------------------+---------------+
# | target(sodium_channel_inhibitor)                        |        0.0191 |
# +---------------------------------------------------------+---------------+
# | target(sphingosine_receptor_agonist)                    |        0.0008 |
# +---------------------------------------------------------+---------------+
# | target(src_inhibitor)                                   |        0.0008 |
# +---------------------------------------------------------+---------------+
# | target(steroid)                                         |        0.0000 |
# +---------------------------------------------------------+---------------+
# | target(syk_inhibitor)                                   |        0.0008 |
# +---------------------------------------------------------+---------------+
# | target(tachykinin_antagonist)                           |        0.0048 |
# +---------------------------------------------------------+---------------+
# | target(tgf-beta_receptor_inhibitor)                     |        0.0008 |
# +---------------------------------------------------------+---------------+
# | target(thrombin_inhibitor)                              |        0.0016 |
# +---------------------------------------------------------+---------------+
# | target(thymidylate_synthase_inhibitor)                  |        0.0024 |
# +---------------------------------------------------------+---------------+
# | target(tlr_agonist)                                     |        0.0016 |
# +---------------------------------------------------------+---------------+
# | target(tlr_antagonist)                                  |        0.0000 |
# +---------------------------------------------------------+---------------+
# | target(tnf_inhibitor)                                   |        0.0024 |
# +---------------------------------------------------------+---------------+
# | target(topoisomerase_inhibitor)                         |        0.0056 |
# +---------------------------------------------------------+---------------+
# | target(transient_receptor_potential_channel_antagonist) |        0.0016 |
# +---------------------------------------------------------+---------------+
# | target(tropomyosin_receptor_kinase_inhibitor)           |        0.0008 |
# +---------------------------------------------------------+---------------+
# | target(trpv_agonist)                                    |        0.0016 |
# +---------------------------------------------------------+---------------+
# | target(trpv_antagonist)                                 |        0.0032 |
# +---------------------------------------------------------+---------------+
# | target(tubulin_inhibitor)                               |        0.0095 |
# +---------------------------------------------------------+---------------+
# | target(tyrosine_kinase_inhibitor)                       |        0.0048 |
# +---------------------------------------------------------+---------------+
# | target(ubiquitin_specific_protease_inhibitor)           |        0.0008 |
# +---------------------------------------------------------+---------------+
# | target(vegfr_inhibitor)                                 |        0.0135 |
# +---------------------------------------------------------+---------------+
# | target(vitamin_b)                                       |        0.0024 |
# +---------------------------------------------------------+---------------+
# | target(vitamin_d_receptor_agonist)                      |        0.0032 |
# +---------------------------------------------------------+---------------+
# | target(wnt_inhibitor)                                   |        0.0016 |
# +---------------------------------------------------------+---------------+
